# %% [markdown]
# # Customer Churn Analysis

# %% [markdown]
# Below is my analysis on customer churn using telecomm data sourced from Kaggle. It will include 1) Exploratory Data Analysis, 2) Modeling, and 3) Conclusions.

# %%
# Customer Analysis and EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import ptitprince

# Machine Learning
## Feature Scaling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

## ML Models Diffrent Algorithms
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

## Metrics
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay

## Comparision of Performance of all Algorithms
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 21
#      19 ## Metrics
#      20 from sklearn.metrics import classification_report
# ---> 21 from sklearn.metrics import plot_confusion_matrix
#      23 ## Comparision of Performance of all Algorithms
#      24 from sklearn.metrics import roc_auc_score
#
# ImportError: cannot import name 'plot_confusion_matrix' from 'sklearn.metrics' (c:\Users\Eric\Downloads\mlproject\.venv\Lib\site-packages\sklearn\metrics\__init__.py)

# %%
df = pd.read_csv('../input/telecom-churn/telecom_churn.csv')
df
